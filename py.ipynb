# %%
from pycaret.utils import version
from pycaret.datasets import get_data
import pandas as pd

# %%
data=pd.read_csv("house.csv")
boston_df=pd.read_csv("house.csv")
from pycaret.regression import*
reg=setup(data=boston_df,target="price",data_split_shuffle=False)
# Out:
# <style  type="text/css" >
# </style><table id="T_aabc3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aabc3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aabc3_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_aabc3_row0_col1" class="data row0 col1" >1840</td>
#             </tr>
#             <tr>
#                         <th id="T_aabc3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_aabc3_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_aabc3_row1_col1" class="data row1 col1" >price</td>
#             </tr>
#             <tr>
#                         <th id="T_aabc3_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models(turbo=False)
setup(data=boston_df,target="price",feature_selection=True,feature_selection_threshold=0.8)
compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=124)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          12:29:15
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .      Kernel Ridge
# <style  type="text/css" >
#     #T_5bcfb_ th {
#           text-align: left;
# ...
